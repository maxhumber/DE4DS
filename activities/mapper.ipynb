# %% [markdown]
# ### Activity
#
# Fill in the `DataFrameMapper` code to binarize the positions and scale the goals...

# %%
import pandas as pd
from sklearn.preprocessing import LabelBinarizer, StandardScaler
from sklearn_pandas import DataFrameMapper

X = pd.DataFrame({
    'position': ['C', 'C', 'D', 'RW', 'D'],
    'goals': [1, 0, 0, 1, 2]
})

mapper = DataFrameMapper(
    # < your code here >
    # standard scale "goals"
    # label binarize "position"
)

mapper.fit(X)
mapper.transform(X)
